# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Peer exercise 1

# %% [markdown]
# ## Introduction
# This notebook provides an overview of essential tools and languages used in data science, along with practical examples.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Tools
#
# | Type                 | Tools                          |
# |----------------------|--------------------------------|
# | IDEs                 | Jupyter, RStudio, PyCharm      |
# | Data Visualization   | Matplotlib, Seaborn, ggplot2   |
# | Machine Learning     | TensorFlow, PyTorch, Keras    |

# %% [markdown]
# ## Arithmetic Expression Examples
# Examples of arithmetic expressions include addition (e.g., 2 + 2), subtraction (e.g., 5 - 3), multiplication (e.g., 4 * 6), and division (e.g., 8 / 2).

# %%
1+2*6
# Out:
# 13

# %%
# Function to convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example usage
minutes = 120
print(f"{minutes} minutes is equal to {minutes_to_hours(minutes)} hours.")
# Out:
# 120 minutes is equal to 2.0 hours.

# %% [markdown]
# ## Objectives
# - Understand the key languages and libraries in data science.
# - Learn about various data science tools.
# - Perform basic arithmetic operations and conversions in code.

# %% [markdown]
# ## Author
# [Zhongzhong Niu]
